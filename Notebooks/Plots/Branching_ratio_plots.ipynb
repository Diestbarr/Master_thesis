# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from numpy.random import normal

# %%
Observables = pd.read_pickle("Observables")

Observables
# Out:
#      N_Obs              Name         Bin Experiment   Th_Pred    Th_Err  \
# 0        1   Br(B+-->K+mumu)  [0.1,0.98]       LHCb  0.324879  0.094645
# 1        2   Br(B+-->K+mumu)     [1.1,2]       LHCb  0.332050  0.097295
# 2        3   Br(B+-->K+mumu)       [2,3]       LHCb  0.366464  0.109133
# 3        4   Br(B+-->K+mumu)       [3,4]       LHCb  0.363699  0.111008
# 4        5   Br(B+-->K+mumu)       [4,5]       LHCb  0.360746  0.113595
# ..     ...               ...         ...        ...       ...       ...
# 232    233   FH(B+-->K+mumu)       [1,2]       CMS8  0.046462  0.005015
# 233    234  AFB(B+-->K+mumu)       [1,2]       CMS8  0.000000  0.000000
# 234    235   FH(B+-->K+mumu)     [2,4.3]       CMS8  0.023362  0.002519
# 235    236  AFB(B+-->K+mumu)     [2,4.3]       CMS8  0.000000  0.000000
# 236    237   FH(B+-->K+mumu)  [4.3,8.68]       CMS8  0.012188  0.001280
#
#      Exp_Value   Exp_Err      Diff  Joint_Err
# 0      0.29216  0.022000 -0.032719   0.097169
# ...

# %%
Branchings = Observables[Observables["Name"].str.contains("Br")]

Branchings
# Out:
#      N_Obs              Name         Bin Experiment   Th_Pred    Th_Err  \
# 0        1   Br(B+-->K+mumu)  [0.1,0.98]       LHCb  0.324879  0.094645
# 1        2   Br(B+-->K+mumu)     [1.1,2]       LHCb  0.332050  0.097295
# 2        3   Br(B+-->K+mumu)       [2,3]       LHCb  0.366464  0.109133
# 3        4   Br(B+-->K+mumu)       [3,4]       LHCb  0.363699  0.111008
# 4        5   Br(B+-->K+mumu)       [4,5]       LHCb  0.360746  0.113595
# 5        6   Br(B+-->K+mumu)       [5,6]       LHCb  0.357712  0.116894
# 6        7   Br(B+-->K+mumu)       [6,7]       LHCb  0.354966  0.121354
# 7        8   Br(B+-->K+mumu)       [7,8]       LHCb  0.353737  0.129354
# 8        9   Br(B0-->K0mumu)     [0.1,2]       LHCb  0.651081  0.189956
# 9       10   Br(B0-->K0mumu)       [2,4]       LHCb  0.677691  0.204149
# 10      11   Br(B0-->K0mumu)       [4,6]       LHCb  0.666846  0.213798
# 11      12   Br(B0-->K0mumu)       [6,8]       LHCb  0.657836  0.232274
# ...

# %%
B_plus_to_K_plus = pd.DataFrame(Branchings[Branchings["Name"]=="Br(B+-->K+mumu)"]) #Extracts the branching ratios of the B+ -> K+ process

B_plus_to_K_plus
# Out:
#     N_Obs             Name         Bin Experiment   Th_Pred    Th_Err  \
# 0       1  Br(B+-->K+mumu)  [0.1,0.98]       LHCb  0.324879  0.094645
# 1       2  Br(B+-->K+mumu)     [1.1,2]       LHCb  0.332050  0.097295
# 2       3  Br(B+-->K+mumu)       [2,3]       LHCb  0.366464  0.109133
# 3       4  Br(B+-->K+mumu)       [3,4]       LHCb  0.363699  0.111008
# 4       5  Br(B+-->K+mumu)       [4,5]       LHCb  0.360746  0.113595
# 5       6  Br(B+-->K+mumu)       [5,6]       LHCb  0.357712  0.116894
# 6       7  Br(B+-->K+mumu)       [6,7]       LHCb  0.354966  0.121354
# 7       8  Br(B+-->K+mumu)       [7,8]       LHCb  0.353737  0.129354
# 12     13  Br(B+-->K+mumu)     [15,22]       LHCb  1.020250  0.133992
#
#     Exp_Value  Exp_Err      Diff  Joint_Err
# 0     0.29216   0.0220 -0.032719   0.097169
# 1     0.20970   0.0171 -0.122350   0.098786
# 2     0.28200   0.0210 -0.084464   0.111136
# 3     0.25400   0.0200 -0.109699   0.112795
# ...

# %%
B_zero_to_K_zero = pd.DataFrame(Branchings[Branchings["Name"]=="Br(B0-->K0mumu)"]) #Extracts the branching ratios of the B0 -> K0 process

B_zero_to_K_zero
# Out:
#     N_Obs             Name      Bin Experiment   Th_Pred    Th_Err  Exp_Value  \
# 8       9  Br(B0-->K0mumu)  [0.1,2]       LHCb  0.651081  0.189956     0.2318
# 9      10  Br(B0-->K0mumu)    [2,4]       LHCb  0.677691  0.204149     0.3740
# 10     11  Br(B0-->K0mumu)    [4,6]       LHCb  0.666846  0.213798     0.3460
# 11     12  Br(B0-->K0mumu)    [6,8]       LHCb  0.657836  0.232274     0.5400
# 13     14  Br(B0-->K0mumu)  [15,22]       LHCb  0.947435  0.124433     0.6650
#
#     Exp_Err      Diff  Joint_Err
# 8    0.1121 -0.419281   0.220567
# 9    0.1120 -0.303691   0.232854
# 10   0.1080 -0.320846   0.239528
# 11   0.1200 -0.117836   0.261440
# 13   0.1190 -0.282435   0.172176

# %%
B_zero_to_K_star = pd.DataFrame(Branchings[Branchings["Name"]=="Br(B0-->K0*mumu)"]) #Extracts the branching ratios of the B0 -> K* process

B_zero_to_K_star
# Out:
#      N_Obs              Name         Bin Experiment   Th_Pred    Th_Err  \
# 110    111  Br(B0-->K0*mumu)  [0.1,0.98]       LHCb  0.874524  0.816386
# 111    112  Br(B0-->K0*mumu)   [1.1,2.5]       LHCb  0.542492  0.343942
# 112    113  Br(B0-->K0*mumu)     [2.5,4]       LHCb  0.566827  0.389796
# 113    114  Br(B0-->K0*mumu)       [4,6]       LHCb  0.887122  0.659725
# 114    115  Br(B0-->K0*mumu)       [6,8]       LHCb  1.089350  0.893789
# 115    116  Br(B0-->K0*mumu)     [15,19]       LHCb  2.532080  0.220802
#
#      Exp_Value   Exp_Err      Diff  Joint_Err
# 110    0.89408  0.092005  0.019556   0.821554
# 111    0.45640  0.056140 -0.086092   0.348493
# 112    0.50100  0.061828 -0.065827   0.394669
# 113    0.70800  0.074458 -0.179122   0.663913
# 114    0.85800  0.083066 -0.231350   0.897640
# 115    1.74400  0.144776 -0.788080   0.264033

# %%
B_plus_to_K_star = pd.DataFrame(Branchings[Branchings["Name"]=="Br(B+-->K+*mumu)"]) #Extracts the branching ratios of the B+ -> K+* process

B_plus_to_K_star
# Out:
#      N_Obs              Name      Bin Experiment   Th_Pred    Th_Err  \
# 116    117  Br(B+-->K+*mumu)  [0.1,2]       LHCb  1.346280  1.084232
# 117    118  Br(B+-->K+*mumu)    [2,4]       LHCb  0.820954  0.552383
# 118    119  Br(B+-->K+*mumu)    [4,6]       LHCb  0.969091  0.715592
# 119    120  Br(B+-->K+*mumu)    [6,8]       LHCb  1.183010  0.966327
# 120    121  Br(B+-->K+*mumu)  [15,19]       LHCb  2.726570  0.237771
#
#      Exp_Value  Exp_Err      Diff  Joint_Err
# 116     1.1248    0.266 -0.221480   1.116385
# 117     1.1180    0.320  0.297046   0.638378
# 118     0.4980    0.200 -0.471091   0.743015
# 119     0.6600    0.220 -0.523010   0.991054
# 120     1.5800    0.320 -1.146570   0.398667

# %% [markdown]
# Let's add the central value of the bin and the length from the center to the end of the interval

# %%
B_plus_to_K_plus["CM"] = [0.54,1.55,2.5,3.5,4.5,5.5,6.5,7.5,18.5] #Class mark of each bin
B_plus_to_K_plus["Side"] = [0.44,0.45,0.5,0.5,0.5,0.5,0.5,0.5,3.5] #Side length of each bin

B_plus_to_K_plus
# Out:
#     N_Obs             Name         Bin Experiment   Th_Pred    Th_Err  \
# 0       1  Br(B+-->K+mumu)  [0.1,0.98]       LHCb  0.324879  0.094645
# 1       2  Br(B+-->K+mumu)     [1.1,2]       LHCb  0.332050  0.097295
# 2       3  Br(B+-->K+mumu)       [2,3]       LHCb  0.366464  0.109133
# 3       4  Br(B+-->K+mumu)       [3,4]       LHCb  0.363699  0.111008
# 4       5  Br(B+-->K+mumu)       [4,5]       LHCb  0.360746  0.113595
# 5       6  Br(B+-->K+mumu)       [5,6]       LHCb  0.357712  0.116894
# 6       7  Br(B+-->K+mumu)       [6,7]       LHCb  0.354966  0.121354
# 7       8  Br(B+-->K+mumu)       [7,8]       LHCb  0.353737  0.129354
# 12     13  Br(B+-->K+mumu)     [15,22]       LHCb  1.020250  0.133992
#
#     Exp_Value  Exp_Err      Diff  Joint_Err     CM  Side
# 0     0.29216   0.0220 -0.032719   0.097169   0.54  0.44
# 1     0.20970   0.0171 -0.122350   0.098786   1.55  0.45
# 2     0.28200   0.0210 -0.084464   0.111136   2.50  0.50
# ...

# %%
B_zero_to_K_zero["CM"] = [1.05,3,5,7,18.5] #Class mark of each bin
B_zero_to_K_zero["Side"] = [0.95,1,1,1,3.5] #Side length of each bin

B_zero_to_K_zero
# Out:
#     N_Obs             Name      Bin Experiment   Th_Pred    Th_Err  Exp_Value  \
# 8       9  Br(B0-->K0mumu)  [0.1,2]       LHCb  0.651081  0.189956     0.2318
# 9      10  Br(B0-->K0mumu)    [2,4]       LHCb  0.677691  0.204149     0.3740
# 10     11  Br(B0-->K0mumu)    [4,6]       LHCb  0.666846  0.213798     0.3460
# 11     12  Br(B0-->K0mumu)    [6,8]       LHCb  0.657836  0.232274     0.5400
# 13     14  Br(B0-->K0mumu)  [15,22]       LHCb  0.947435  0.124433     0.6650
#
#     Exp_Err      Diff  Joint_Err     CM  Side
# 8    0.1121 -0.419281   0.220567   1.05  0.95
# 9    0.1120 -0.303691   0.232854   3.00  1.00
# 10   0.1080 -0.320846   0.239528   5.00  1.00
# 11   0.1200 -0.117836   0.261440   7.00  1.00
# 13   0.1190 -0.282435   0.172176  18.50  3.50

# %%
B_zero_to_K_star["CM"] = [0.54,1.8,3.25,5,7,17] #Class mark of each bin
B_zero_to_K_star["Side"] = [0.44,0.7,0.75,1,1,2] #Side length of each bin

B_zero_to_K_star
# Out:
#      N_Obs              Name         Bin Experiment   Th_Pred    Th_Err  \
# 110    111  Br(B0-->K0*mumu)  [0.1,0.98]       LHCb  0.874524  0.816386
# 111    112  Br(B0-->K0*mumu)   [1.1,2.5]       LHCb  0.542492  0.343942
# 112    113  Br(B0-->K0*mumu)     [2.5,4]       LHCb  0.566827  0.389796
# 113    114  Br(B0-->K0*mumu)       [4,6]       LHCb  0.887122  0.659725
# 114    115  Br(B0-->K0*mumu)       [6,8]       LHCb  1.089350  0.893789
# 115    116  Br(B0-->K0*mumu)     [15,19]       LHCb  2.532080  0.220802
#
#      Exp_Value   Exp_Err      Diff  Joint_Err     CM  Side
# 110    0.89408  0.092005  0.019556   0.821554   0.54  0.44
# 111    0.45640  0.056140 -0.086092   0.348493   1.80  0.70
# 112    0.50100  0.061828 -0.065827   0.394669   3.25  0.75
# 113    0.70800  0.074458 -0.179122   0.663913   5.00  1.00
# 114    0.85800  0.083066 -0.231350   0.897640   7.00  1.00
# 115    1.74400  0.144776 -0.788080   0.264033  17.00  2.00

# %%
B_plus_to_K_star["CM"] = [1.05,3,5,7,17] #Class mark of each bin
B_plus_to_K_star["Side"] = [0.95,1,1,1,2] #Side length of each bin

B_plus_to_K_star
# Out:
#      N_Obs              Name      Bin Experiment   Th_Pred    Th_Err  \
# 116    117  Br(B+-->K+*mumu)  [0.1,2]       LHCb  1.346280  1.084232
# 117    118  Br(B+-->K+*mumu)    [2,4]       LHCb  0.820954  0.552383
# 118    119  Br(B+-->K+*mumu)    [4,6]       LHCb  0.969091  0.715592
# 119    120  Br(B+-->K+*mumu)    [6,8]       LHCb  1.183010  0.966327
# 120    121  Br(B+-->K+*mumu)  [15,19]       LHCb  2.726570  0.237771
#
#      Exp_Value  Exp_Err      Diff  Joint_Err     CM  Side
# 116     1.1248    0.266 -0.221480   1.116385   1.05  0.95
# 117     1.1180    0.320  0.297046   0.638378   3.00  1.00
# 118     0.4980    0.200 -0.471091   0.743015   5.00  1.00
# 119     0.6600    0.220 -0.523010   0.991054   7.00  1.00
# 120     1.5800    0.320 -1.146570   0.398667  17.00  2.00

# %% [markdown]
# Let's plot the comparisons

# %%
x = B_plus_to_K_plus.CM
Side = B_plus_to_K_plus.Side
Th = B_plus_to_K_plus.Th_Pred
Exp = B_plus_to_K_plus.Exp_Value
sigma_Th = B_plus_to_K_plus.Th_Err
sigma_Exp = B_plus_to_K_plus.Exp_Err


fig,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

ax.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")
ax.legend(loc="upper left")


ax.set_ylabel("Branching ratio", fontsize=16)
ax.set_xlim(-0.5,8.5)


ax2.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax2.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")

ax2.set_xlim(14.5,22.5)


#Sets the broken x axis

ax.spines.right.set_visible(False)
ax2.spines.left.set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.yaxis.tick_right()

fig.tight_layout()

d = .7  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax.plot([1, 1], [0, 1], transform=ax.transAxes, **kwargs)
ax2.plot([0, 0], [1, 0], transform=ax2.transAxes, **kwargs)





fig.suptitle(r'$B^+ \to \: K^+ \mu^+ \mu^-$', x=0.55, y=1.05, va="top", fontsize=16)
fig.supxlabel(r'$q(GeV^2)$', fontsize=16, x=0.55, y=-0.05)



#plt.savefig("B_plus_to_K_plus.jpg", bbox_inches='tight', dpi=300)
plt.show()

# %%
x = B_zero_to_K_zero.CM
Side = B_zero_to_K_zero.Side
Th = B_zero_to_K_zero.Th_Pred
Exp = B_zero_to_K_zero.Exp_Value
sigma_Th = B_zero_to_K_zero.Th_Err
sigma_Exp = B_zero_to_K_zero.Exp_Err


fig,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

ax.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")
ax.legend(loc="upper left")


ax.set_ylabel("Branching ratio", fontsize=16)
ax.set_xlim(-0.5,8.5)


ax2.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax2.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")

ax2.set_xlim(14.5,22.5)


#Sets the broken x axis

ax.spines.right.set_visible(False)
ax2.spines.left.set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.yaxis.tick_right()

fig.tight_layout()

d = .7  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax.plot([1, 1], [0, 1], transform=ax.transAxes, **kwargs)
ax2.plot([0, 0], [1, 0], transform=ax2.transAxes, **kwargs)





fig.suptitle(r'$B^0 \to \: K^0 \: \mu^+ \mu^-$', x=0.55, y=1.05, va="top", fontsize=16)
fig.supxlabel(r'$q(GeV^2)$', fontsize=16, x=0.55, y=-0.05)



#plt.savefig("B_zero_to_K_zero.jpg", bbox_inches='tight', dpi=300)
plt.show()

# %%
x = B_zero_to_K_star.CM
Side = B_zero_to_K_star.Side
Th = B_zero_to_K_star.Th_Pred
Exp = B_zero_to_K_star.Exp_Value
sigma_Th = B_zero_to_K_star.Th_Err
sigma_Exp = B_zero_to_K_star.Exp_Err


fig,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

ax.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")
ax.legend(loc="upper left")


ax.set_ylabel("Branching ratio", fontsize=16)
ax.set_xlim(-0.5,8.5)


ax2.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax2.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")

ax2.set_xlim(14.5,19.5)


#Sets the broken x axis

ax.spines.right.set_visible(False)
ax2.spines.left.set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.yaxis.tick_right()

fig.tight_layout()

d = .7  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax.plot([1, 1], [0, 1], transform=ax.transAxes, **kwargs)
ax2.plot([0, 0], [1, 0], transform=ax2.transAxes, **kwargs)





fig.suptitle(r'$B^0 \to \: K^{0*} \: \mu^+ \mu^-$', x=0.55, y=1.05, va="top", fontsize=16)
fig.supxlabel(r'$q(GeV^2)$', fontsize=16, x=0.55, y=-0.05)



#plt.savefig("B_zero_to_K_star.jpg", bbox_inches='tight', dpi=300)
plt.show()

# %%
x = B_plus_to_K_star.CM
Side = B_plus_to_K_star.Side
Th = B_plus_to_K_star.Th_Pred
Exp = B_plus_to_K_star.Exp_Value
sigma_Th = B_plus_to_K_star.Th_Err
sigma_Exp = B_plus_to_K_star.Exp_Err


fig,(ax,ax2) = plt.subplots(1,2,sharey=True, facecolor='w')

ax.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")
ax.legend(loc="upper left")


ax.set_ylabel("Branching ratio", fontsize=16)
ax.set_xlim(-0.5,8.5)


ax2.errorbar(x,Th,xerr=Side, yerr=sigma_Th, linestyle='', capsize=3, label="Theory")
ax2.errorbar(x,Exp,xerr=Side, yerr=sigma_Exp, linestyle='', capsize=3, label="Experiment")

ax2.set_xlim(14.5,19.5)


#Sets the broken x axis

ax.spines.right.set_visible(False)
ax2.spines.left.set_visible(False)
ax.yaxis.tick_left()
ax.tick_params(labeltop=False)  # don't put tick labels at the top
ax2.yaxis.tick_right()

fig.tight_layout()

d = .7  # proportion of vertical to horizontal extent of the slanted line
kwargs = dict(marker=[(-1, -d), (1, d)], markersize=12,
              linestyle="none", color='k', mec='k', mew=1, clip_on=False)
ax.plot([1, 1], [0, 1], transform=ax.transAxes, **kwargs)
ax2.plot([0, 0], [1, 0], transform=ax2.transAxes, **kwargs)





fig.suptitle(r'$B^+ \to \: K^{+*} \: \mu^+ \mu^-$', x=0.55, y=1.05, va="top", fontsize=16)
fig.supxlabel(r'$q(GeV^2)$', fontsize=16, x=0.55, y=-0.05)



#plt.savefig("B_plus_to_K_star.jpg", bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# Lets compute the chi^2 difference

# %%
Chi = np.array((B_plus_to_K_plus.Diff/B_plus_to_K_plus["Joint_Err"])**2) #Calculates the contribution for each piece of the chi^2
bins = np.array(B_plus_to_K_plus.Bin) #Stores the bins in an array

sum_chi = np.round(np.sum(Chi),2)

plt.bar(bins,Chi)
plt.title(r'$B^+ \to \: K^+ \mu^+ \mu^-$', fontsize=16)
plt.xlabel(r'$q(GeV^2)$', fontsize=16)
plt.ylabel(r'$\chi^2$', fontsize=16)

plt.text(x=6, y=1.2, s=r'$\chi^2=$%s'%sum_chi)

#plt.savefig("Chi_B_plus_to_K_plus.jpg",bbox_inches="tight", dpi=300)

plt.show()

# %%
Chi = np.array((B_zero_to_K_zero.Diff/B_zero_to_K_zero["Joint_Err"])**2) #Calculates the contribution for each piece of the chi^2
bins = np.array(B_zero_to_K_zero.Bin) #Stores the bins in an array

sum_chi = np.round(np.sum(Chi),2)

plt.bar(bins,Chi)
plt.title(r'$B^0 \to \: K^0 \: \mu^+ \mu^-$', fontsize=16)
plt.xlabel(r'$q(GeV^2)$', fontsize=16)
plt.ylabel(r'$\chi^2$', fontsize=16)

plt.text(x=2, y=2.5, s=r'$\chi^2=$%s'%sum_chi)

#plt.savefig("Chi_B_zero_to_K_zero.jpg",bbox_inches="tight", dpi=300)

plt.show()

# %%
Chi = np.array((B_zero_to_K_star.Diff/B_zero_to_K_star["Joint_Err"])**2) #Calculates the contribution for each piece of the chi^2
bins = np.array(B_zero_to_K_star.Bin) #Stores the bins in an array

sum_chi = np.round(np.sum(Chi),2)

plt.bar(bins,Chi)
plt.title(r'$B^0 \to \: K^0* \: \mu^+ \mu^-$', fontsize=16)
plt.xlabel(r'$q(GeV^2)$', fontsize=16)
plt.ylabel(r'$\chi^2$', fontsize=16)

plt.text(x=2, y=6, s=r'$\chi^2=$%s'%sum_chi)

#plt.savefig("Chi_B_zero_to_K_star.jpg",bbox_inches="tight", dpi=300)

plt.show()

# %%
Chi = np.array((B_plus_to_K_star.Diff/B_plus_to_K_star["Joint_Err"])**2) #Calculates the contribution for each piece of the chi^2
bins = np.array(B_plus_to_K_star.Bin) #Stores the bins in an array

sum_chi = np.round(np.sum(Chi),2)

plt.bar(bins,Chi)
plt.title(r'$B^+ \to \: K^{+*} \: \mu^+ \mu^-$', fontsize=16)
plt.xlabel(r'$q(GeV^2)$', fontsize=16)
plt.ylabel(r'$\chi^2$', fontsize=16)

plt.text(x=2, y=6, s=r'$\chi^2=$%s'%sum_chi)

plt.savefig("Chi_B_plus_to_K_star.jpg",bbox_inches="tight", dpi=300)

plt.show()

# %%
#Converts every dataframe to pickle

B_plus_to_K_plus.to_pickle("B_plus_to_K_plus")
B_zero_to_K_zero.to_pickle("B_zero_to_K_zero")
B_zero_to_K_star.to_pickle("B_zero_to_K_star")
B_plus_to_K_star.to_pickle("B_plus_to_K_star")

# %% [markdown]
# # Multiplot

# %%
x1 = B_zero_to_K_zero.CM[0:4]
Side1 = B_zero_to_K_zero.Side[0:4]
Th1 = B_zero_to_K_zero.Th_Pred[0:4]
Exp1 = B_zero_to_K_zero.Exp_Value[0:4]
sigma_Th1 = B_zero_to_K_zero.Th_Err[0:4]
sigma_Exp1 = B_zero_to_K_zero.Exp_Err[0:4]


x2 = B_zero_to_K_star.CM[0:5]
Side2 = B_zero_to_K_star.Side[0:5]
Th2 = B_zero_to_K_star.Th_Pred[0:5]
Exp2 = B_zero_to_K_star.Exp_Value[0:5]
sigma_Th2 = B_zero_to_K_star.Th_Err[0:5]
sigma_Exp2 = B_zero_to_K_star.Exp_Err[0:5]


x3 = B_plus_to_K_plus.CM[0:8]
Side3 = B_plus_to_K_plus.Side[0:8]
Th3 = B_plus_to_K_plus.Th_Pred[0:8]
Exp3 = B_plus_to_K_plus.Exp_Value[0:8]
sigma_Th3 = B_plus_to_K_plus.Th_Err[0:8]
sigma_Exp3 = B_plus_to_K_plus.Exp_Err[0:8]

x4 = B_plus_to_K_star.CM[0:4]
Side4 = B_plus_to_K_star.Side[0:4]
Th4 = B_plus_to_K_star.Th_Pred[0:4]
Exp4 = B_plus_to_K_star.Exp_Value[0:4]
sigma_Th4 = B_plus_to_K_star.Th_Err[0:4]
sigma_Exp4 = B_plus_to_K_star.Exp_Err[0:4]




fig,((ax1,ax2), (ax3,ax4)) = plt.subplots(2,2,sharey=True, sharex= True, facecolor='w')

fig.tight_layout(pad=3.0)

ax1.errorbar(x1,Th1,xerr=Side1, yerr=sigma_Th1, linestyle='', capsize=3, label="Theory")
ax1.errorbar(x1,Exp1,xerr=Side1, yerr=sigma_Exp1, linestyle='', capsize=3, label="Experiment")
ax1.set_title(r'$B^0 \to \: K^0 \: \mu^+\mu^-$')
ax1.set_ylabel('$10^7 \cdot \mathcal{B}$')
#ax1.legend(loc="upper left")

ax2.errorbar(x2,Th2,xerr=Side2, yerr=sigma_Th2, linestyle='', capsize=3, label="Theory")
ax2.errorbar(x2,Exp2,xerr=Side2, yerr=sigma_Exp2, linestyle='', capsize=3, label="Experiment")
ax2.set_title(r'$B^0 \to \: K^{0*} \: \mu^+\mu^-$')
#ax2.legend(loc="upper left")

ax3.errorbar(x3,Th3,xerr=Side3, yerr=sigma_Th3, linestyle='', capsize=3, label="Theory")
ax3.errorbar(x3,Exp3,xerr=Side3, yerr=sigma_Exp3, linestyle='', capsize=3, label="Experiment")
ax3.set_title(r'$B^+ \to \: K^+ \: \mu^+\mu^-$')
ax3.set_xlabel(r'$q^2 \: (GeV^2)$')
ax3.set_ylabel('$10^7 \cdot \mathcal{B}$')
#ax3.legend(loc="upper left")

ax4.errorbar(x4,Th4,xerr=Side4, yerr=sigma_Th4, linestyle='', capsize=3, label="Theory")
ax4.errorbar(x4,Exp4,xerr=Side4, yerr=sigma_Exp4, linestyle='', capsize=3, label="Experiment")
ax4.set_title(r'$B^+ \to \: K^{+*} \: \mu^+\mu^-$')
ax4.set_xlabel(r'$q^2 \: (GeV^2)$')
#ax4.legend(loc="upper left")

plt.savefig('Branching_deficits.jpg', format="jpg", dpi=300, bbox_inches="tight")
plt.show()
